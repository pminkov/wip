# %%
import matplotlib.pyplot as plt
a = [(10, 0.00356), (20, 0.00838), (40, 0.00874), (80, 0.00904), (160, 0.0089), (320, 0.00904), (640, 0.00743), (1280, 0.01026), (2560, 0.01338), (5120, 0.01449)]
normalized_times = [x[1] for x in a]
    
sizes = [x[0] for x in a]
plt.plot(normalized_times)
plt.show()
print sizes
# Out:
# [10, 20, 40, 80, 160, 320, 640, 1280, 2560, 5120]

# %%
# a = [(800, 0.00648), (840, 0.0062), (880, 0.00731), (920, 0.00871), (960, 0.01019), (1000, 0.00845), (1040, 0.0104), (1080, 0.01146), (1120, 0.01149), (1160, 0.01184), (1200, 0.01239), (1240, 0.01374), (1280, 0.01508), (1320, 0.01506), (1360, 0.01536), (1400, 0.01617), (1440, 0.01785), (1480, 0.01888), (1520, 0.01911), (1560, 0.01874)]
a = [(400, 0.00365), (470, 0.00425), (540, 0.00417), (610, 0.0047), (680, 0.00569), (750, 0.00636), (820, 0.00633), (890, 0.00667), (960, 0.00945), (1030, 0.01046), (1100, 0.01033), (1170, 0.01276), (1240, 0.01321), (1310, 0.0145), (1380, 0.01639), (1450, 0.01792), (1520, 0.02045), (1590, 0.01929), (1660, 0.02123), (1730, 0.02158), (1800, 0.02303), (1870, 0.02459), (1940, 0.02442), (2010, 0.02441), (2080, 0.02641), (2150, 0.02878), (2220, 0.02917), (2290, 0.02885), (2360, 0.03065), (2430, 0.034), (2500, 0.03398), (2570, 0.03496), (2640, 0.03514), (2710, 0.03644), (2780, 0.03716), (2850, 0.03793), (2920, 0.03932), (2990, 0.04129), (3060, 0.04203), (3130, 0.04307)]
pos = [x[0] for x in a]
times = [x[1] for x in a]
plt.plot(pos, times)
plt.show()
